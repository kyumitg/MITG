# %%
import matplotlib.pyplot as plt
import random as rd
import numpy as np
import DataRead as dr

# %%
x = np.zeros(shape=(300))

for i in range(300):
    x[i] = rd.uniform(-0.1,0.6)
    #print(x[i])
    
plt.rcParams["figure.figsize"] = (20,5)
plt.rcParams['axes.grid'] = True
plt.plot(x)
plt.show()

# %%
dataCount = 1
fileFullPath = "./ECG/ECG-ID Database/person_02/rec_"

sig,fields,ann,FileteredSig = dr.LoadData(dataCount,fileFullPath)

# %%
sig[0].shape
print(fields)
# Out:
# [ {'fs': 500, 'sig_name': ['ECG I', 'ECG I filtered'], 'n_sig': 2, 'base_time': None, 'base_date': None, 'units': ['mV', 'mV'], 'sig_len': 10000, 'comments': ['Age: 23', 'Sex: female', 'ECG date: 07.12.2004']}]

# %%
plt.plot(sig[0][:10000,1])
plt.show()

# %%
x_trash_data = []
y_trash_label = []

for dataCount in range(500):
    temp = np.zeros(shape=(300))
    for dataSize in range(300):
        temp[dataSize] = rd.uniform(-0.1,0.6)
    x_trash_data.append(temp)
    y_trash_label.append([1,0,0])
    
x_trash_data = np.array(x_trash_data)
y_trash_label = np.array(y_trash_label)

# %%
for data in x_trash_data:
    plt.plot(data)
